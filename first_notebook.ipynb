# %% [markdown]
# <a href="https://colab.research.google.com/github/MasamiMitsuhashi/colab_sample/blob/main/first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# #おめでとう！
# ##最初のコードを実行できました。
#
# 人工知能を学んで行きましょう。
# Google colaboratoryを使いこなしましょう。
#
# LaTexで数式を入力することもできます。
# $$y = \frac{1}{x}$$
# $$y = 1\div{x}$$
